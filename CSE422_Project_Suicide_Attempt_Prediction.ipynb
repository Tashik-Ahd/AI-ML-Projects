# %% [markdown]
# <a href="https://colab.research.google.com/github/Tashik-Ahd/AI-ML-Projects/blob/main/CSE422_Project_Suicide_Attempt_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
suicide = pd.read_csv('/content/foreveralone.csv')
suicide.head()
# Out:
#                  time gender sexuallity  age              income  \
# 0  5/17/2016 20:04:18   Male   Straight   35  $30,000 to $39,999
# 1  5/17/2016 20:04:30   Male   Bisexual   21       $1 to $10,000
# 2  5/17/2016 20:04:58   Male   Straight   22                  $0
# 3  5/17/2016 20:08:01   Male   Straight   19       $1 to $10,000
# 4  5/17/2016 20:08:04   Male   Straight   23  $30,000 to $39,999
#
#                  race     bodyweight virgin prostitution_legal  \
# 0  White non-Hispanic  Normal weight    Yes                 No
# 1  White non-Hispanic    Underweight    Yes                 No
# 2  White non-Hispanic     Overweight    Yes                 No
# 3  White non-Hispanic     Overweight    Yes                Yes
# 4  White non-Hispanic     Overweight     No                 No
#
#       pay_for_sex  friends social_fear depressed  \
# 0              No      0.0         Yes       Yes
# 1              No      0.0         Yes       Yes
# 2              No     10.0         Yes       Yes
# 3              No      8.0         Yes       Yes
# 4  Yes and I have     10.0          No       Yes
#
#                                what_help_from_others attempt_suicide  \
# 0           wingman/wingwoman, Set me up with a date             Yes
# 1  wingman/wingwoman, Set me up with a date, date...              No
# 2                                  I don't want help              No
# 3                                      date coaching              No
# 4                                  I don't want help              No
#
#                                        employment           job_title  \
# 0                              Employed for wages  mechanical drafter
# 1                Out of work and looking for work                   -
# 2  Out of work but not currently looking for work          unemployed
# 3                                       A student             student
# 4                              Employed for wages      Factory worker
#
#                                            edu_level  \
# 0                                   Associate degree
# 1                            Some college, no degree
# 2                            Some college, no degree
# 3                            Some college, no degree
# 4  High school graduate, diploma or the equivalen...
#
#                improve_yourself_how
# 0                               NaN
# 1  join clubs/socual clubs/meet ups
# 2                    Other exercise
# 3        Joined a gym/go to the gym
# 4                               NaN

# %%
for column in suicide.columns:
    print(f"Unique value counts for {column}:")
    print(suicide[column].value_counts())
    print()
# Out:
# Unique value counts for time:
# time
# 5/18/2016 7:41:18     2
# 5/17/2016 20:04:18    1
# 5/18/2016 17:26:15    1
# 5/18/2016 18:44:01    1
# 5/18/2016 18:32:30    1
#                      ..
# 5/18/2016 3:06:44     1
# 5/18/2016 3:06:09     1
# 5/18/2016 3:04:00     1
# 5/18/2016 2:58:31     1
# 9/4/2016 23:10:04     1
# Name: count, Length: 468, dtype: int64
#
# Unique value counts for gender:
# gender
# Male                  393
# Female                 73
# Transgender male        2
# Transgender female      1
# Name: count, dtype: int64
#
# Unique value counts for sexuallity:
# sexuallity
# Straight       415
# Bisexual        46
# Gay/Lesbian      8
# Name: count, dtype: int64
#
# Unique value counts for age:
# age
# 23    46
# 21    41
# 22    40
# 20    39
# 18    39
# 24    37
# 19    32
# 25    30
# 26    26
# 28    21
# 30    16
# 27    15
# 29    14
# 17    13
# 31    10
# 33     6
# 35     6
# 32     5
# 16     5
# 15     4
# 38     4
# 34     3
# 12     2
# 36     2
# 37     2
# 39     2
# 70     1
# 45     1
# 55     1
# 57     1
# 44     1
# 41     1
# 14     1
# 48     1
# 42     1
# Name: count, dtype: int64
#
# Unique value counts for income:
# income
# $0                      160
# $1 to $10,000           100
# $10,000 to $19,999       58
# $20,000 to $29,999       44
# $30,000 to $39,999       39
# $50,000 to $74,999       28
# $40,000 to $49,999       16
# $75,000 to $99,999        9
# $125,000 to $149,999      6
# $100,000 to $124,999      3
# $150,000 to $174,999      2
# $174,999 to $199,999      2
# $200,000 or more          2
# Name: count, dtype: int64
#
# Unique value counts for race:
# race
# White non-Hispanic                                                                 336
# Asian                                                                               54
# Hispanic (of any race)                                                              32
# Black                                                                               22
# Mixed                                                                                3
# Middle Eastern                                                                       2
# Indian                                                                               2
# half Arab                                                                            1
# Mixed race                                                                           1
# First two answers. Gender is androgyne, not male; sexuality is asexual, not bi.      1
# White and Native American                                                            1
# Half Asian half white                                                                1
# North African                                                                        1
# Native American mix                                                                  1
# Multi                                                                                1
# indian                                                                               1
# Mixed white/asian                                                                    1
# mixed                                                                                1
# white and asian                                                                      1
# Native american                                                                      1
# caucasian                                                                            1
# Turkish                                                                              1
# helicopterkin                                                                        1
# Pakistani                                                                            1
# European                                                                             1
# Name: count, dtype: int64
#
# Unique value counts for bodyweight:
# bodyweight
# Normal weight    269
# Overweight       113
# Underweight       62
# Obese             25
# Name: count, dtype: int64
#
# Unique value counts for virgin:
# virgin
# Yes    352
# No     117
# Name: count, dtype: int64
#
# Unique value counts for prostitution_legal:
# prostitution_legal
# No     361
# Yes    108
# Name: count, dtype: int64
#
# Unique value counts for pay_for_sex:
# pay_for_sex
# No                   318
# Yes but I haven't    129
# Yes and I have        22
# Name: count, dtype: int64
#
# Unique value counts for friends:
# friends
# 0.0      109
# 1.0       54
# 5.0       45
# 3.0       44
# 2.0       42
# 10.0      34
# 4.0       27
# 6.0       26
# 20.0      16
# 15.0      12
# 7.0       10
# 8.0       10
# 12.0       8
# 30.0       6
# 13.0       3
# 16.0       3
# 40.0       3
# 17.0       2
# 9.0        2
# 100.0      2
# 25.0       2
# 600.0      1
# 11.0       1
# 400.0      1
# 0.2        1
# 18.0       1
# 60.0       1
# 28.0       1
# 80.0       1
# 0.5        1
# Name: count, dtype: int64
#
# Unique value counts for social_fear:
# social_fear
# Yes    308
# No     161
# Name: count, dtype: int64
#
# Unique value counts for depressed:
# depressed
# Yes    312
# No     157
# Name: count, dtype: int64
#
# Unique value counts for what_help_from_others:
# what_help_from_others
# I don't want help                                                                                                                222
# wingman/wingwoman, Set me up with a date, date coaching                                                                           52
# Set me up with a date                                                                                                             51
# wingman/wingwoman, Set me up with a date                                                                                          36
# date coaching                                                                                                                     24
# wingman/wingwoman                                                                                                                 21
# Set me up with a date, date coaching                                                                                              11
# wingman/wingwoman, date coaching                                                                                                   6
# wingman/wingwoman, Set me up with a date, I don't want help                                                                        3
# Friendship                                                                                                                         2
# wingman/wingwoman, Set me up with a date, date coaching, Any help                                                                  1
# wingman/wingwoman, Set me up with a date, date coaching, I don't really know. Something magical that would make me happy.          1
# wingman/wingwoman, Set me up with a date, date coaching, Therapy, shoulder to cry on                                               1
# Just want mates that make it look like I fit in                                                                                    1
# date coaching, It would be nice but why would a woman choose me?  There are plenty better                                          1
# therapy                                                                                                                            1
# I don't want help, Like, to be seen & treated like a normal person                                                                 1
# i lost faith and hope                                                                                                              1
# Teach me how to talk to people                                                                                                     1
# I don't want help, kill me                                                                                                         1
# Emotional support                                                                                                                  1
# just more friends/greater social life in general tbh                                                                               1
# coping with being beyond help                                                                                                      1
# I don't want help, More general stuff                                                                                              1
# I don't know                                                                                                                       1
# I used to want all of those things. Now it is too late for any of them to make a difference.                                       1
# wingman/wingwoman, Set me up with a date, invite me to shit please                                                                 1
# I have no idea                                                                                                                     1
# Set me up with a date, I don't want help                                                                                           1
# Money for rehab or sober living home                                                                                               1
# not sure what would help                                                                                                           1
# Friends                                                                                                                            1
# I don't want any help. I can't even talk about it.                                                                                 1
# wingman/wingwoman, Set me up with a date, date coaching, someone to kill.me                                                        1
# wingman/wingwoman, someone to hang out with me where I can meet met (e.g. class, free event) and sell me up                        1
# wingman/wingwoman, Set me up with a date, date coaching, anything                                                                  1
# Set me up with a date, Friends                                                                                                     1
# wingman/wingwoman, Set me up with a date, I don't even know..                                                                      1
# Trust                                                                                                                              1
# date coaching, I don't want help                                                                                                   1
# I want help but I am not sure what kind. I always think it would be nice if a woman would approch me but thats not realistic.      1
# fitness coaching                                                                                                                   1
# wingman/wingwoman, Set me up with a date, Pity fuck                                                                                1
# Maybe to learn how to be happy                                                                                                     1
# Im on my own                                                                                                                       1
# help getting a better job                                                                                                          1
# I'm not fa lol                                                                                                                     1
# I don't want help, more one night stands                                                                                           1
# date coaching, social skills training                                                                                              1
# There is no way that they can help. They only give useless advice like "just be more confident".                                   1
# wingman/wingwoman, Set me up with a date, date coaching, I don't want help                                                         1
# Name: count, dtype: int64
#
# Unique value counts for attempt_suicide:
# attempt_suicide
# No     384
# Yes     85
# Name: count, dtype: int64
#
# Unique value counts for employment:
# employment
# A student                                         174
# Employed for wages                                171
# Out of work but not currently looking for work     40
# Out of work and looking for work                   38
# Self-employed                                      22
# Unable to work                                     13
# Military                                            5
# Retired                                             3
# A homemaker                                         3
# Name: count, dtype: int64
#
# Unique value counts for job_title:
# job_title
# Student                         50
# student                         25
# none                            17
# Unemployed                      11
# Engineer                         9
#                                 ..
# Zivildiener (austrian stuff)     1
# ggg                              1
# RN                               1
# Freelance writer                 1
# Scientist                        1
# Name: count, Length: 274, dtype: int64
#
# Unique value counts for edu_level:
# edu_level
# Some college, no degree                                               137
# Bachelor’s degree                                                     120
# High school graduate, diploma or the equivalent (for example: GED)     93
# Some high school, no diploma                                           50
# Master’s degree                                                        28
# Associate degree                                                       18
# Trade/technical/vocational training                                    12
# Professional degree                                                     6
# Doctorate degree                                                        5
# Name: count, dtype: int64
#
# Unique value counts for improve_yourself_how:
# improve_yourself_how
# Other exercise                                                                                                   51
# Joined a gym/go to the gym                                                                                       47
# Joined a gym/go to the gym, Other exercise, join clubs/socual clubs/meet ups                                     24
# Joined a gym/go to the gym, Other exercise                                                                       24
# Other exercise, join clubs/socual clubs/meet ups                                                                 23
#                                                                                                                  ..
# Therapy, join clubs/socual clubs/meet ups, medication                                                             1
# Trying to accept my fate.                                                                                         1
# Therapy, Other exercise, diets, change of wardrobe, medication, diet pills                                        1
# Joined a gym/go to the gym, Therapy, Self analysis                                                                1
# Cosmetic surgery, Joined a gym/go to the gym, Therapy, Other exercise, join clubs/socual clubs/meet ups, None     1
# Name: count, Length: 61, dtype: int64

# %%
# Label Encoding to run heatmap

le = LabelEncoder()
suicide = suicide.apply(lambda col: le.fit_transform(col))

# %%
# Heat map (non-numerical)

corr_matrix = suicide.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=False, fmt=".2f", cmap='coolwarm')
plt.show()

# %%
# Heatmap (numerical)

correlation = suicide.corr()
plt.figure(figsize=(16,10))
plt.title('Correlation Heatmap of Suicide Attempts')
ax = sns.heatmap(correlation, square=True, annot=True, fmt='.2f', linecolor='white')
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
ax.set_yticklabels(ax.get_yticklabels(), rotation=30)
plt.show()

# %%
suicide = pd.read_csv('/content/foreveralone.csv')

# %%
f, ax = plt.subplots(figsize=(6, 8))
ax = sns.countplot(x="attempt_suicide", data=suicide, palette="Set2")
plt.show()
# Out:
# <ipython-input-34-7d62498b13f2>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x="attempt_suicide", data=suicide, palette="Set2")

# %%
suicide.isnull().sum()
# Out:
# time                       0
# gender                     0
# sexuallity                 0
# age                        0
# income                     0
# race                       0
# bodyweight                 0
# virgin                     0
# prostitution_legal         0
# pay_for_sex                0
# friends                    0
# social_fear                0
# depressed                  0
# what_help_from_others      0
# attempt_suicide            0
# employment                 0
# job_title                 24
# edu_level                  0
# improve_yourself_how     106
# dtype: int64

# %%
# Deal with null values

suicide = suicide.drop(['job_title'], axis = 1)

suicide.head()
# Out:
#                  time gender sexuallity  age              income  \
# 0  5/17/2016 20:04:18   Male   Straight   35  $30,000 to $39,999
# 1  5/17/2016 20:04:30   Male   Bisexual   21       $1 to $10,000
# 2  5/17/2016 20:04:58   Male   Straight   22                  $0
# 3  5/17/2016 20:08:01   Male   Straight   19       $1 to $10,000
# 4  5/17/2016 20:08:04   Male   Straight   23  $30,000 to $39,999
#
#                  race     bodyweight virgin prostitution_legal  \
# 0  White non-Hispanic  Normal weight    Yes                 No
# 1  White non-Hispanic    Underweight    Yes                 No
# 2  White non-Hispanic     Overweight    Yes                 No
# 3  White non-Hispanic     Overweight    Yes                Yes
# 4  White non-Hispanic     Overweight     No                 No
#
#       pay_for_sex  friends social_fear depressed  \
# 0              No      0.0         Yes       Yes
# 1              No      0.0         Yes       Yes
# 2              No     10.0         Yes       Yes
# 3              No      8.0         Yes       Yes
# 4  Yes and I have     10.0          No       Yes
#
#                                what_help_from_others attempt_suicide  \
# 0           wingman/wingwoman, Set me up with a date             Yes
# 1  wingman/wingwoman, Set me up with a date, date...              No
# 2                                  I don't want help              No
# 3                                      date coaching              No
# 4                                  I don't want help              No
#
#                                        employment  \
# 0                              Employed for wages
# 1                Out of work and looking for work
# 2  Out of work but not currently looking for work
# 3                                       A student
# 4                              Employed for wages
#
#                                            edu_level  \
# 0                                   Associate degree
# 1                            Some college, no degree
# 2                            Some college, no degree
# 3                            Some college, no degree
# 4  High school graduate, diploma or the equivalen...
#
#                improve_yourself_how
# 0                               NaN
# 1  join clubs/socual clubs/meet ups
# 2                    Other exercise
# 3        Joined a gym/go to the gym
# 4                               NaN

# %%
# Drop less priortised columns/columns that require NLP

suicide = suicide.drop(['improve_yourself_how', 'time', 'what_help_from_others'], axis = 1)

suicide.head()
# Out:
#   gender sexuallity  age              income                race  \
# 0   Male   Straight   35  $30,000 to $39,999  White non-Hispanic
# 1   Male   Bisexual   21       $1 to $10,000  White non-Hispanic
# 2   Male   Straight   22                  $0  White non-Hispanic
# 3   Male   Straight   19       $1 to $10,000  White non-Hispanic
# 4   Male   Straight   23  $30,000 to $39,999  White non-Hispanic
#
#       bodyweight virgin prostitution_legal     pay_for_sex  friends  \
# 0  Normal weight    Yes                 No              No      0.0
# 1    Underweight    Yes                 No              No      0.0
# 2     Overweight    Yes                 No              No     10.0
# 3     Overweight    Yes                Yes              No      8.0
# 4     Overweight     No                 No  Yes and I have     10.0
#
#   social_fear depressed attempt_suicide  \
# 0         Yes       Yes             Yes
# 1         Yes       Yes              No
# 2         Yes       Yes              No
# 3         Yes       Yes              No
# 4          No       Yes              No
#
#                                        employment  \
# 0                              Employed for wages
# 1                Out of work and looking for work
# 2  Out of work but not currently looking for work
# 3                                       A student
# 4                              Employed for wages
#
#                                            edu_level
# 0                                   Associate degree
# 1                            Some college, no degree
# 2                            Some college, no degree
# 3                            Some college, no degree
# 4  High school graduate, diploma or the equivalen...

# %%
# deleting income, race
suicide = suicide.drop(['income', 'race'], axis = 1)

# %%
# one-hot encoding bodyweight

encoded_columns = pd.get_dummies(suicide['bodyweight'])

# Drop the original column from 'df'
suicide = suicide.drop('bodyweight', axis=1)

# Concatenate the one-hot encoded columns with the original DataFrame
suicide = pd.concat([suicide, encoded_columns], axis=1)


suicide.head()
# Out:
#   gender sexuallity  age virgin prostitution_legal     pay_for_sex  friends  \
# 0   Male   Straight   35    Yes                 No              No      0.0
# 1   Male   Bisexual   21    Yes                 No              No      0.0
# 2   Male   Straight   22    Yes                 No              No     10.0
# 3   Male   Straight   19    Yes                Yes              No      8.0
# 4   Male   Straight   23     No                 No  Yes and I have     10.0
#
#   social_fear depressed attempt_suicide  \
# 0         Yes       Yes             Yes
# 1         Yes       Yes              No
# 2         Yes       Yes              No
# 3         Yes       Yes              No
# 4          No       Yes              No
#
#                                        employment  \
# 0                              Employed for wages
# 1                Out of work and looking for work
# 2  Out of work but not currently looking for work
# 3                                       A student
# 4                              Employed for wages
#
#                                            edu_level  Normal weight  Obese  \
# 0                                   Associate degree           True  False
# 1                            Some college, no degree          False  False
# 2                            Some college, no degree          False  False
# 3                            Some college, no degree          False  False
# 4  High school graduate, diploma or the equivalen...          False  False
#
#    Overweight  Underweight
# 0       False        False
# 1       False         True
# 2        True        False
# 3        True        False
# 4        True        False

# %%
# one-hot encoding gender

encoded_columns = pd.get_dummies(suicide['gender'])

# Drop the original column from 'df'
suicide = suicide.drop('gender', axis=1)

# Concatenate the one-hot encoded columns with the original DataFrame
suicide = pd.concat([suicide, encoded_columns], axis=1)


suicide.head()
suicide.shape
# Out:
# (469, 19)

# %%
# one-hot encoding sexuallity

encoded_columns = pd.get_dummies(suicide['sexuallity'])

# Drop the original column from suicide
suicide = suicide.drop('sexuallity', axis=1)

# Concatenate the one-hot encoded columns with the original DataFrame
suicide = pd.concat([suicide, encoded_columns], axis=1)

suicide.head()
# Out:
#    age virgin prostitution_legal     pay_for_sex  friends social_fear  \
# 0   35    Yes                 No              No      0.0         Yes
# 1   21    Yes                 No              No      0.0         Yes
# 2   22    Yes                 No              No     10.0         Yes
# 3   19    Yes                Yes              No      8.0         Yes
# 4   23     No                 No  Yes and I have     10.0          No
#
#   depressed attempt_suicide                                      employment  \
# 0       Yes             Yes                              Employed for wages
# 1       Yes              No                Out of work and looking for work
# 2       Yes              No  Out of work but not currently looking for work
# 3       Yes              No                                       A student
# 4       Yes              No                              Employed for wages
#
#                                            edu_level  ...  Obese  Overweight  \
# 0                                   Associate degree  ...  False       False
# 1                            Some college, no degree  ...  False       False
# 2                            Some college, no degree  ...  False        True
# 3                            Some college, no degree  ...  False        True
# 4  High school graduate, diploma or the equivalen...  ...  False        True
#
#    Underweight  Female  Male  Transgender female  Transgender male  Bisexual  \
# 0        False   False  True               False             False     False
# 1         True   False  True               False             False      True
# 2        False   False  True               False             False     False
# 3        False   False  True               False             False     False
# 4        False   False  True               False             False     False
#
#    Gay/Lesbian  Straight
# 0        False      True
# 1        False     False
# 2        False      True
# 3        False      True
# 4        False      True
#
# [5 rows x 21 columns]

# %%
# binary mapping columns: virgin, prostitution_legal, pay_for_sex, social_fear, depressed, attempt_suicide

suicide['virgin'] = suicide['virgin'].map({'Yes':1,'No':0})

suicide['prostitution_legal'] = suicide['prostitution_legal'].map({'Yes':1,'No':0})

suicide['pay_for_sex'] = suicide['pay_for_sex'].map({'No':0,"Yes but I haven't": 0, "Yes and I have": 1})

suicide['social_fear'] = suicide['social_fear'].map({'Yes':1,'No':0})

suicide['depressed'] = suicide['depressed'].map({'Yes':1,'No':0})

suicide['attempt_suicide'] = suicide['attempt_suicide'].map({'Yes':1,'No':0})

suicide.head()

suicide.isnull().sum()
# Out:
# age                   0
# virgin                0
# prostitution_legal    0
# pay_for_sex           0
# friends               0
# social_fear           0
# depressed             0
# attempt_suicide       0
# employment            0
# edu_level             0
# Normal weight         0
# Obese                 0
# Overweight            0
# Underweight           0
# Female                0
# Male                  0
# Transgender female    0
# Transgender male      0
# Bisexual              0
# Gay/Lesbian           0
# Straight              0
# dtype: int64

# %%
# mapping edu-level (degree vs non-degree)

suicide['edu_level'] = suicide['edu_level'].map({'Some college, no degree':0, 'High school graduate, diploma or the equivalent (for example: GED)': 0,
                                           'Some high school, no diploma': 0, 'Trade/technical/vocational training': 0,
                                           'Bachelor’s degree':1, 'Master’s degree':1, 'Associate degree':1,
                                           'Professional degree':1, 'Doctorate degree':1})


print(suicide['edu_level'])
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 464    1
# 465    0
# 466    0
# 467    0
# 468    1
# Name: edu_level, Length: 469, dtype: int64

# %%
# mapping employment (currently working vs currently unemployed)

suicide['employment'] = suicide['employment'].map({'A student': 1, 'Employed for wages': 1, 'Self-employed': 1,
                                                 'Out of work but not currently looking for work': 0,
                                                 'Out of work and looking for work':0, 'Unable to work': 0, 'Military': 0,
                                                 'Retired': 0, 'A homemaker': 0})


print(suicide['employment'])
# Out:
# 0      1
# 1      0
# 2      0
# 3      1
# 4      1
#       ..
# 464    1
# 465    1
# 466    1
# 467    0
# 468    1
# Name: employment, Length: 469, dtype: int64

# %%
suicide.head()
# Out:
#    age  virgin  prostitution_legal  pay_for_sex  friends  social_fear  \
# 0   35       1                   0            0      0.0            1
# 1   21       1                   0            0      0.0            1
# 2   22       1                   0            0     10.0            1
# 3   19       1                   1            0      8.0            1
# 4   23       0                   0            1     10.0            0
#
#    depressed  attempt_suicide  employment  edu_level  ...  Obese  Overweight  \
# 0          1                1           1          1  ...  False       False
# 1          1                0           0          0  ...  False       False
# 2          1                0           0          0  ...  False        True
# 3          1                0           1          0  ...  False        True
# 4          1                0           1          0  ...  False        True
#
#    Underweight  Female  Male  Transgender female  Transgender male  Bisexual  \
# 0        False   False  True               False             False     False
# 1         True   False  True               False             False      True
# 2        False   False  True               False             False     False
# 3        False   False  True               False             False     False
# 4        False   False  True               False             False     False
#
#    Gay/Lesbian  Straight
# 0        False      True
# 1        False     False
# 2        False      True
# 3        False      True
# 4        False      True
#
# [5 rows x 21 columns]

# %%
# Assuming 'attempt_suicide' is the target variable and rest are features
features = ['age', 'virgin', 'prostitution_legal', 'pay_for_sex', 'friends',
            'social_fear', 'depressed', 'employment', 'edu_level', 'Normal weight',
            'Obese', 'Overweight', 'Underweight', 'Female', 'Male', 'Transgender female',
            'Transgender male', 'Bisexual', 'Gay/Lesbian', 'Straight']
X = suicide[features]  # Features
y = suicide['attempt_suicide']  # Target variable

# %%
# scaling features
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

suicide[['friends', 'age']] = scaler.fit_transform(suicide[['friends', 'age']])

suicide.head()
# Out:
#         age  virgin  prostitution_legal  pay_for_sex   friends  social_fear  \
# 0  0.396552       1                   0            0  0.000000            1
# 1  0.155172       1                   0            0  0.000000            1
# 2  0.172414       1                   0            0  0.016667            1
# 3  0.120690       1                   1            0  0.013333            1
# 4  0.189655       0                   0            1  0.016667            0
#
#    depressed  attempt_suicide  employment  edu_level  ...  Obese  Overweight  \
# 0          1                1           1          1  ...  False       False
# 1          1                0           0          0  ...  False       False
# 2          1                0           0          0  ...  False        True
# 3          1                0           1          0  ...  False        True
# 4          1                0           1          0  ...  False        True
#
#    Underweight  Female  Male  Transgender female  Transgender male  Bisexual  \
# 0        False   False  True               False             False     False
# 1         True   False  True               False             False      True
# 2        False   False  True               False             False     False
# 3        False   False  True               False             False     False
# 4        False   False  True               False             False     False
#
#    Gay/Lesbian  Straight
# 0        False      True
# 1        False     False
# 2        False      True
# 3        False      True
# 4        False      True
#
# [5 rows x 21 columns]

# %%
# label_encoder = LabelEncoder()
# y = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42,stratify = y)

# %%
# Initialize the Logistic Regression classifier
logistic_classifier = LogisticRegression(max_iter=1000, random_state=42)

# Train the classifier using the training data
logistic_classifier.fit(X_train, y_train)

# Predict using the test data
logistic_y_pred = logistic_classifier.predict(X_test)

# Evaluate the accuracy of the classifier
logistic_accuracy = metrics.accuracy_score(y_test, logistic_y_pred)
print(f"logistic regression Accuracy: {logistic_accuracy}")

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test, logistic_y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Logistic Regression')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Calculate precision, recall, and F1-score and display classification report
print("Classification Report:")
print(classification_report(y_test, logistic_y_pred, target_names=['Class 0', 'Class 1']))
# Out:
# logistic regression Accuracy: 0.8156028368794326
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      0.97      0.90       115
#      Class 1       0.50      0.12      0.19        26
#
#     accuracy                           0.82       141
#    macro avg       0.66      0.54      0.54       141
# weighted avg       0.77      0.82      0.77       141

# %%
#For KNN
x = suicide.columns.tolist

# Getting all the features and setting x and y variables
features = ['age', 'virgin', 'prostitution_legal', 'pay_for_sex', 'friends',
            'social_fear', 'depressed', 'employment', 'edu_level', 'Normal weight',
            'Obese', 'Overweight', 'Underweight', 'Female', 'Male', 'Transgender female',
            'Transgender male', 'Bisexual', 'Gay/Lesbian', 'Straight']
X = suicide[features]  # Features
y = suicide['attempt_suicide']

# %%
# Split the data into training and testing sets and setting 30% of the dataset as test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)  # No stratify as accuracy decrease


# Initialize the K-Nearest Neighbors classifier
knn_classifier = KNeighborsClassifier(n_neighbors=5)

# Train the classifier using the training data
knn_classifier.fit(X_train, y_train)

# Predict using the test data
knn_y_pred = knn_classifier.predict(X_test)

# %%
# Evaluate the accuracy of the classifier
knn_accuracy = metrics.accuracy_score(y_test, knn_y_pred)
print(f"KNN Accuracy: {knn_accuracy}")

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test, knn_y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - KNN')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Calculate precision, recall, and F1-score and display classification report
print("Classification Report:")
print(classification_report(y_test, knn_y_pred, target_names=['Class 0', 'Class 1']))
# Out:
# KNN Accuracy: 0.8085106382978723
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.84      0.95      0.89       117
#      Class 1       0.33      0.12      0.18        24
#
#     accuracy                           0.81       141
#    macro avg       0.59      0.54      0.54       141
# weighted avg       0.75      0.81      0.77       141

# %%
#For Decision Tree
# Split the data into training and testing sets and setting 30% of the dataset as test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 1)   # No stratify as accuracy decrease
obj = DecisionTreeClassifier(criterion = 'gini', random_state = 1)                              # bux uses entropy

obj.fit(X_train, y_train)
decision_tree_y_pred = obj.predict(X_test)

Decision_tree_score = accuracy_score(decision_tree_y_pred, y_test)
print(f"Decision tree accuracy {Decision_tree_score}")

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test, decision_tree_y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Decision tree')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Calculate precision, recall, and F1-score and display classification report
print("Classification Report:")
print(classification_report(y_test, decision_tree_y_pred, target_names=['Class 0', 'Class 1']))
# Out:
# Decision tree accuracy 0.8014184397163121
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.85      0.92      0.89       118
#      Class 1       0.31      0.17      0.22        23
#
#     accuracy                           0.80       141
#    macro avg       0.58      0.55      0.55       141
# weighted avg       0.76      0.80      0.78       141

# %%
# SVM


# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


# # linear kernel
# obj_svm = svm.SVC(kernel='linear')

# # polynomial kernel
# obj_svm = svm.SVC(kernel='poly', degree=20)

# radial basis function (RBF) kernel
obj_svm = svm.SVC(kernel='rbf', C=1.0, gamma='auto')

# obj_svm = svm.SVC(kernel='rbf', C=10.0, gamma='auto')
# obj_svm = svm.SVC(kernel='rbf', C=100.0, gamma='auto')
# obj_svm = svm.SVC(kernel='rbf', C=0.1, gamma='auto')

# Train the classifier
obj_svm.fit(X_train, y_train)

# Make predictions on the test set
y_pred = obj_svm.predict(X_test)

# Calculate the accuracy
svm_accuracy = accuracy_score(y_test, y_pred)
print(f'SVM Accuracy: {svm_accuracy}')

# Compute confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - SVM')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# Calculate precision, recall, and F1-score and display classification report
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=['Class 0', 'Class 1']))
# Out:
# SVM Accuracy: 0.8297872340425532
# Classification Report:
#               precision    recall  f1-score   support
#
#      Class 0       0.83      1.00      0.91       117
#      Class 1       0.00      0.00      0.00        24
#
#     accuracy                           0.83       141
#    macro avg       0.41      0.50      0.45       141
# weighted avg       0.69      0.83      0.75       141
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Train and evaluate models
accuracies = {
    "Logistic Regression":logistic_accuracy,
    "KNN":knn_accuracy,
    "Decision Tree": Decision_tree_score,
    "SVM":svm_accuracy
}

# Plotting bar chart
plt.figure(figsize=(10, 6))
plt.bar(accuracies.keys(), accuracies.values())
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Accuracy of Different Models')
plt.ylim(0.0, 1.0)  # Set y-axis limits between 0 and 1 for accuracy
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
